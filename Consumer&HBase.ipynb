# %% [markdown]
# # Consumer & HBase

# %%
from kafka import KafkaConsumer
import json
import happybase

# Initialize Kafka consumer
consumer = KafkaConsumer(
    'publictransportstream',  # Topic name
    bootstrap_servers=['192.168.113.33:9092'],  # Adjust to your Kafka broker address
    auto_offset_reset='latest',
    enable_auto_commit=True,
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))  # Deserialize JSON data
)

# Connect to HBase Thrift Server
connection = happybase.Connection(host='localhost')  # Replace 'localhost' with HBase server address
connection.open()

# Define the table name and column family
table_name = 'public_transport'
column_family = 'cf'

# Check if the table exists; create it if it doesn't
if table_name.encode() not in connection.tables():
    connection.create_table(
        table_name,
        {column_family: dict()}  # Define the column family
    )

# Access the HBase table
table = connection.table(table_name)

# Consume messages and write to HBase
print("Listening for messages...")
for message in consumer:
    data = message.value  # Deserialize the message
    print(f"Received: {data}")
    
    # Prepare data for HBase (ensure column family prefix)
    row_key = str(data.get('timestamp', 'nan')) 
    hbase_data = {
        f"{column_family}:transition_date": data.get('transition_date', ''),
        f"{column_family}:transition_hour": str(data.get('transition_hour', '')),
        f"{column_family}:line": data.get('line', ''),
        f"{column_family}:number_of_passenger": str(data.get('number_of_passenger', '')),
        f"{column_family}:station_poi_desc_cd": str(data.get('station_poi_desc_cd', 'nan')),
        f"{column_family}:timestamp": str(data.get('timestamp', 'nan'))
    }
    
    # Write to HBase
    table.put(row_key, hbase_data)
    print(f"Data written to HBase with row key: {row_key}")
# Out:
# Listening for messages...
# Received: {'transition_date': '2023-12-31', 'transition_hour': 12, 'line': 'BOSTANCI - DUDULLU', 'number_of_passenger': 4, 'station_poi_desc_cd': 'BOSTANCI', 'timestamp': '2023-12-31T12:00:00'}
# Data written to HBase with row key: 2023-12-31T12:00:00
# Received: {'transition_date': '2023-03-28', 'transition_hour': 19, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 5, 'station_poi_desc_cd': 'SISHANE GUNEY', 'timestamp': '2023-03-28T19:00:00'}
# Data written to HBase with row key: 2023-03-28T19:00:00
# Received: {'transition_date': '2023-12-14', 'transition_hour': 15, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 118, 'station_poi_desc_cd': 'SOGANLIK', 'timestamp': '2023-12-14T15:00:00'}
# Data written to HBase with row key: 2023-12-14T15:00:00
# Received: {'transition_date': '2023-03-03', 'transition_hour': 20, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 3, 'station_poi_desc_cd': 'KADIKOY (DOGU)', 'timestamp': '2023-03-03T20:00:00'}
# Data written to HBase with row key: 2023-03-03T20:00:00
# Received: {'transition_date': '2023-03-31', 'transition_hour': 8, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'AYRILIKCESME', 'timestamp': '2023-03-31T08:00:00'}
# Data written to HBase with row key: 2023-03-31T08:00:00
# Received: {'transition_date': '2023-06-02', 'transition_hour': 8, 'line': 'Y.KADIKOY-KABATAS', 'number_of_passenger': 30, 'station_poi_desc_cd': 'KADIKOY YENI', 'timestamp': '2023-06-02T08:00:00'}
# Data written to HBase with row key: 2023-06-02T08:00:00
# Received: {'transition_date': '2023-11-15', 'transition_hour': 7, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 3, 'station_poi_desc_cd': 'KADIKOY (DOGU)', 'timestamp': '2023-11-15T07:00:00'}
# Data written to HBase with row key: 2023-11-15T07:00:00
# Received: {'transition_date': '2023-12-30', 'transition_hour': 16, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 71, 'station_poi_desc_cd': 'BEREC', 'timestamp': '2023-12-30T16:00:00'}
# Data written to HBase with row key: 2023-12-30T16:00:00
# Received: {'transition_date': '2023-01-28', 'transition_hour': 18, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 2, 'station_poi_desc_cd': 'YUNUS', 'timestamp': '2023-01-28T18:00:00'}
# Data written to HBase with row key: 2023-01-28T18:00:00
# Received: {'transition_date': '2023-09-09', 'transition_hour': 11, 'line': 'BARBAROS-E.KADIKOY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'BARBAROS', 'timestamp': '2023-09-09T11:00:00'}
# Data written to HBase with row key: 2023-09-09T11:00:00
# Received: {'transition_date': '2023-02-06', 'transition_hour': 16, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ORUCREIS DOGU', 'timestamp': '2023-02-06T16:00:00'}
# Data written to HBase with row key: 2023-02-06T16:00:00
# Received: {'transition_date': '2023-04-27', 'transition_hour': 14, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 3, 'station_poi_desc_cd': 'TOPKAPI', 'timestamp': '2023-04-27T14:00:00'}
# Data written to HBase with row key: 2023-04-27T14:00:00
# Received: {'transition_date': '2023-06-28', 'transition_hour': 8, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 21, 'station_poi_desc_cd': 'ULUBATLI', 'timestamp': '2023-06-28T08:00:00'}
# Data written to HBase with row key: 2023-06-28T08:00:00
# Received: {'transition_date': '2023-03-29', 'transition_hour': 14, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 3, 'station_poi_desc_cd': 'YENIKAPI GUNEY', 'timestamp': '2023-03-29T14:00:00'}
# Data written to HBase with row key: 2023-03-29T14:00:00
# Received: {'transition_date': '2023-09-25', 'transition_hour': 16, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ZEYTINBURNU', 'timestamp': '2023-09-25T16:00:00'}
# Data written to HBase with row key: 2023-09-25T16:00:00
# Received: {'transition_date': '2023-08-02', 'transition_hour': 9, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KARTALTEPE', 'timestamp': '2023-08-02T09:00:00'}
# Data written to HBase with row key: 2023-08-02T09:00:00
# Received: {'transition_date': '2023-02-13', 'transition_hour': 9, 'line': 'TAKSIM - KABATAS', 'number_of_passenger': 1, 'station_poi_desc_cd': 'TAKSIM', 'timestamp': '2023-02-13T09:00:00'}
# Data written to HBase with row key: 2023-02-13T09:00:00
# Received: {'transition_date': '2023-02-03', 'transition_hour': 16, 'line': 'EMINONU-USKUDAR', 'number_of_passenger': 3, 'station_poi_desc_cd': 'KARAKOY', 'timestamp': '2023-02-03T16:00:00'}
# Data written to HBase with row key: 2023-02-03T16:00:00
# Received: {'transition_date': '2023-02-28', 'transition_hour': 13, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 2, 'station_poi_desc_cd': 'KADIKOY (BATI)', 'timestamp': '2023-02-28T13:00:00'}
# Data written to HBase with row key: 2023-02-28T13:00:00
# Received: {'transition_date': '2023-09-04', 'transition_hour': 17, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KAGITHANE DOGU', 'timestamp': '2023-09-04T17:00:00'}
# Data written to HBase with row key: 2023-09-04T17:00:00
# Received: {'transition_date': '2023-05-03', 'transition_hour': 8, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 2, 'station_poi_desc_cd': 'HASTANE (BATI)', 'timestamp': '2023-05-03T08:00:00'}
# Data written to HBase with row key: 2023-05-03T08:00:00
# Received: {'transition_date': '2023-09-15', 'transition_hour': 16, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 8, 'station_poi_desc_cd': 'NECIP FAZIL', 'timestamp': '2023-09-15T16:00:00'}
# Data written to HBase with row key: 2023-09-15T16:00:00
# Received: {'transition_date': '2023-03-14', 'transition_hour': 22, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'YENIBOSNA', 'timestamp': '2023-03-14T22:00:00'}
# Data written to HBase with row key: 2023-03-14T22:00:00
# Received: {'transition_date': '2023-01-28', 'transition_hour': 8, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 3, 'station_poi_desc_cd': 'FETIHKAPI', 'timestamp': '2023-01-28T08:00:00'}
# Data written to HBase with row key: 2023-01-28T08:00:00
# Received: {'transition_date': '2023-12-17', 'transition_hour': 12, 'line': 'BARBAROS-E.KADIKOY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'BARBAROS', 'timestamp': '2023-12-17T12:00:00'}
# Data written to HBase with row key: 2023-12-17T12:00:00
# Received: {'transition_date': '2023-03-17', 'transition_hour': 21, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 42, 'station_poi_desc_cd': 'YENIKAPI-2', 'timestamp': '2023-03-17T21:00:00'}
# Data written to HBase with row key: 2023-03-17T21:00:00
# Received: {'transition_date': '2023-03-18', 'transition_hour': 18, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 3, 'station_poi_desc_cd': 'HACIOSMAN', 'timestamp': '2023-03-18T18:00:00'}
# Data written to HBase with row key: 2023-03-18T18:00:00
# Received: {'transition_date': '2023-01-03', 'transition_hour': 11, 'line': 'EMINONU-ALIBEYKOY', 'number_of_passenger': 20, 'station_poi_desc_cd': 'EYUP TELEFERIK', 'timestamp': '2023-01-03T11:00:00'}
# Data written to HBase with row key: 2023-01-03T11:00:00
# Received: {'transition_date': '2023-11-30', 'transition_hour': 11, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 23, 'station_poi_desc_cd': 'CARSI', 'timestamp': '2023-11-30T11:00:00'}
# Data written to HBase with row key: 2023-11-30T11:00:00
# Received: {'transition_date': '2023-01-17', 'transition_hour': 9, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 3, 'station_poi_desc_cd': '4 LEVENT 2 GUNEY', 'timestamp': '2023-01-17T09:00:00'}
# Data written to HBase with row key: 2023-01-17T09:00:00
# Received: {'transition_date': '2023-02-16', 'transition_hour': 15, 'line': 'KARAKOY-KADIKOY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KARAKOY', 'timestamp': '2023-02-16T15:00:00'}
# Data written to HBase with row key: 2023-02-16T15:00:00
# Received: {'transition_date': '2023-07-07', 'transition_hour': 16, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 4, 'station_poi_desc_cd': 'MITHATPASA', 'timestamp': '2023-07-07T16:00:00'}
# Data written to HBase with row key: 2023-07-07T16:00:00
# Received: {'transition_date': '2023-12-20', 'transition_hour': 13, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 8, 'station_poi_desc_cd': 'PENDIK (BATI)', 'timestamp': '2023-12-20T13:00:00'}
# Data written to HBase with row key: 2023-12-20T13:00:00
# Received: {'transition_date': '2023-04-26', 'transition_hour': 16, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 5, 'station_poi_desc_cd': 'KAYASEHIR MERKEZ', 'timestamp': '2023-04-26T16:00:00'}
# Data written to HBase with row key: 2023-04-26T16:00:00
# Received: {'transition_date': '2023-01-25', 'transition_hour': 16, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 2, 'station_poi_desc_cd': 'ATALAR', 'timestamp': '2023-01-25T16:00:00'}
# Data written to HBase with row key: 2023-01-25T16:00:00
# Received: {'transition_date': '2023-12-31', 'transition_hour': 15, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'M4 KURTKOY', 'timestamp': '2023-12-31T15:00:00'}
# Data written to HBase with row key: 2023-12-31T15:00:00
# Received: {'transition_date': '2023-10-01', 'transition_hour': 12, 'line': 'KABATAS-ADALAR', 'number_of_passenger': 2, 'station_poi_desc_cd': 'YENI KABATAS', 'timestamp': '2023-10-01T12:00:00'}
# Data written to HBase with row key: 2023-10-01T12:00:00
# Received: {'transition_date': '2023-01-20', 'transition_hour': 8, 'line': 'BOGAZ', 'number_of_passenger': 7, 'station_poi_desc_cd': 'BEYLERBEYI', 'timestamp': '2023-01-20T08:00:00'}
# Data written to HBase with row key: 2023-01-20T08:00:00
# Received: {'transition_date': '2023-06-27', 'transition_hour': 15, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 1, 'station_poi_desc_cd': 'SULTANAHMET', 'timestamp': '2023-06-27T15:00:00'}
# Data written to HBase with row key: 2023-06-27T15:00:00
# Received: {'transition_date': '2023-12-21', 'transition_hour': 19, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 22, 'station_poi_desc_cd': 'ZEYTINBURNU', 'timestamp': '2023-12-21T19:00:00'}
# Data written to HBase with row key: 2023-12-21T19:00:00
# Received: {'transition_date': '2023-04-10', 'transition_hour': 18, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 82, 'station_poi_desc_cd': 'KOZYATAGI', 'timestamp': '2023-04-10T18:00:00'}
# Data written to HBase with row key: 2023-04-10T18:00:00
# Received: {'transition_date': '2023-02-20', 'transition_hour': 21, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KARAKOY', 'timestamp': '2023-02-20T21:00:00'}
# Data written to HBase with row key: 2023-02-20T21:00:00
# Received: {'transition_date': '2023-11-27', 'transition_hour': 19, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'VEZNECILER KUZEY', 'timestamp': '2023-11-27T19:00:00'}
# Data written to HBase with row key: 2023-11-27T19:00:00
# Received: {'transition_date': '2023-08-11', 'transition_hour': 19, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 5, 'station_poi_desc_cd': 'KUCUKYALI', 'timestamp': '2023-08-11T19:00:00'}
# Data written to HBase with row key: 2023-08-11T19:00:00
# Received: {'transition_date': '2023-12-18', 'transition_hour': 10, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KISIKLI', 'timestamp': '2023-12-18T10:00:00'}
# Data written to HBase with row key: 2023-12-18T10:00:00
# Received: {'transition_date': '2023-12-16', 'transition_hour': 20, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 4, 'station_poi_desc_cd': 'SIRKECI-2', 'timestamp': '2023-12-16T20:00:00'}
# Data written to HBase with row key: 2023-12-16T20:00:00
# Received: {'transition_date': '2023-03-25', 'transition_hour': 7, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'UCYUZLU', 'timestamp': '2023-03-25T07:00:00'}
# Data written to HBase with row key: 2023-03-25T07:00:00
# Received: {'transition_date': '2023-04-07', 'transition_hour': 17, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 1, 'station_poi_desc_cd': 'GULHANE', 'timestamp': '2023-04-07T17:00:00'}
# Data written to HBase with row key: 2023-04-07T17:00:00
# Received: {'transition_date': '2023-02-23', 'transition_hour': 18, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 2, 'station_poi_desc_cd': 'YAKACIK (BATI)', 'timestamp': '2023-02-23T18:00:00'}
# Data written to HBase with row key: 2023-02-23T18:00:00
# Received: {'transition_date': '2023-04-29', 'transition_hour': 16, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 5, 'station_poi_desc_cd': 'SEHITLIK', 'timestamp': '2023-04-29T16:00:00'}
# Data written to HBase with row key: 2023-04-29T16:00:00
# Received: {'transition_date': '2023-08-16', 'transition_hour': 13, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 7, 'station_poi_desc_cd': 'GOZTEPE BATI', 'timestamp': '2023-08-16T13:00:00'}
# Data written to HBase with row key: 2023-08-16T13:00:00
# Received: {'transition_date': '2023-07-18', 'transition_hour': 15, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 17, 'station_poi_desc_cd': 'SISLI 2 KUZEY', 'timestamp': '2023-07-18T15:00:00'}
# Data written to HBase with row key: 2023-07-18T15:00:00
# Received: {'transition_date': '2023-04-03', 'transition_hour': 20, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 7, 'station_poi_desc_cd': 'ITU GUNEY', 'timestamp': '2023-04-03T20:00:00'}
# Data written to HBase with row key: 2023-04-03T20:00:00
# Received: {'transition_date': '2023-06-25', 'transition_hour': 16, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'M4 KURTKOY', 'timestamp': '2023-06-25T16:00:00'}
# Data written to HBase with row key: 2023-06-25T16:00:00
# Received: {'transition_date': '2023-10-03', 'transition_hour': 16, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 1, 'station_poi_desc_cd': 'MAHMUTBEY M7 HOL 4', 'timestamp': '2023-10-03T16:00:00'}
# Data written to HBase with row key: 2023-10-03T16:00:00
# Received: {'transition_date': '2023-08-11', 'transition_hour': 12, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 34, 'station_poi_desc_cd': 'MAHMUTBEY M7 HOL 2', 'timestamp': '2023-08-11T12:00:00'}
# Data written to HBase with row key: 2023-08-11T12:00:00
# Received: {'transition_date': '2023-01-22', 'transition_hour': 11, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 1, 'station_poi_desc_cd': 'MITHATPASA', 'timestamp': '2023-01-22T11:00:00'}
# Data written to HBase with row key: 2023-01-22T11:00:00
# Received: {'transition_date': '2023-05-04', 'transition_hour': 16, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 24, 'station_poi_desc_cd': '4 LEVENT 2 GUNEY', 'timestamp': '2023-05-04T16:00:00'}
# Data written to HBase with row key: 2023-05-04T16:00:00
# Received: {'transition_date': '2023-02-20', 'transition_hour': 8, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 26, 'station_poi_desc_cd': 'KABATAS 2', 'timestamp': '2023-02-20T08:00:00'}
# Data written to HBase with row key: 2023-02-20T08:00:00
# Received: {'transition_date': '2023-03-12', 'transition_hour': 12, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 3, 'station_poi_desc_cd': 'ATAKOY', 'timestamp': '2023-03-12T12:00:00'}
# Data written to HBase with row key: 2023-03-12T12:00:00
# Received: {'transition_date': '2023-05-06', 'transition_hour': 20, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 21, 'station_poi_desc_cd': 'FATIH', 'timestamp': '2023-05-06T20:00:00'}
# Data written to HBase with row key: 2023-05-06T20:00:00
# Received: {'transition_date': '2023-06-03', 'transition_hour': 19, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 3, 'station_poi_desc_cd': 'USKUDAR 1', 'timestamp': '2023-06-03T19:00:00'}
# Data written to HBase with row key: 2023-06-03T19:00:00
# Received: {'transition_date': '2023-06-04', 'transition_hour': 19, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'CAYIROVA', 'timestamp': '2023-06-04T19:00:00'}
# Data written to HBase with row key: 2023-06-04T19:00:00
# Received: {'transition_date': '2023-03-09', 'transition_hour': 15, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 21, 'station_poi_desc_cd': 'GUZELYALI', 'timestamp': '2023-03-09T15:00:00'}
# Data written to HBase with row key: 2023-03-09T15:00:00
# Received: {'transition_date': '2023-10-19', 'transition_hour': 14, 'line': 'ISTINYE-CUBUKLU', 'number_of_passenger': 8, 'station_poi_desc_cd': 'ISTINYE', 'timestamp': '2023-10-19T14:00:00'}
# Data written to HBase with row key: 2023-10-19T14:00:00
# Received: {'transition_date': '2023-10-11', 'transition_hour': 13, 'line': 'EYUP - PIYERLOTI', 'number_of_passenger': 5, 'station_poi_desc_cd': 'PIERLOTI', 'timestamp': '2023-10-11T13:00:00'}
# Data written to HBase with row key: 2023-10-11T13:00:00
# Received: {'transition_date': '2023-04-27', 'transition_hour': 22, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'GEBZE-1', 'timestamp': '2023-04-27T22:00:00'}
# Data written to HBase with row key: 2023-04-27T22:00:00
# Received: {'transition_date': '2023-01-12', 'transition_hour': 8, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 2, 'station_poi_desc_cd': 'KIRAZLI', 'timestamp': '2023-01-12T08:00:00'}
# Data written to HBase with row key: 2023-01-12T08:00:00
# Received: {'transition_date': '2023-04-21', 'transition_hour': 14, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 11, 'station_poi_desc_cd': 'YENI MAHALLE', 'timestamp': '2023-04-21T14:00:00'}
# Data written to HBase with row key: 2023-04-21T14:00:00
# Received: {'transition_date': '2023-02-24', 'transition_hour': 14, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 3, 'station_poi_desc_cd': 'KARTAL', 'timestamp': '2023-02-24T14:00:00'}
# Data written to HBase with row key: 2023-02-24T14:00:00
# Received: {'transition_date': '2023-05-25', 'transition_hour': 21, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 18, 'station_poi_desc_cd': 'ERENKOY', 'timestamp': '2023-05-25T21:00:00'}
# Data written to HBase with row key: 2023-05-25T21:00:00
# Received: {'transition_date': '2023-10-18', 'transition_hour': 22, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 1, 'station_poi_desc_cd': 'VATAN', 'timestamp': '2023-10-18T22:00:00'}
# Data written to HBase with row key: 2023-10-18T22:00:00
# Received: {'transition_date': '2023-12-01', 'transition_hour': 11, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 164, 'station_poi_desc_cd': 'GUNGOREN', 'timestamp': '2023-12-01T11:00:00'}
# Data written to HBase with row key: 2023-12-01T11:00:00
# Received: {'transition_date': '2023-04-22', 'transition_hour': 11, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 4, 'station_poi_desc_cd': 'FETIHKAPI', 'timestamp': '2023-04-22T11:00:00'}
# Data written to HBase with row key: 2023-04-22T11:00:00
# Received: {'transition_date': '2023-05-04', 'transition_hour': 19, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 2, 'station_poi_desc_cd': 'YENIKAPI GUNEY', 'timestamp': '2023-05-04T19:00:00'}
# Data written to HBase with row key: 2023-05-04T19:00:00
# Received: {'transition_date': '2023-02-22', 'transition_hour': 8, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 1, 'station_poi_desc_cd': 'EDIRNEKAPI', 'timestamp': '2023-02-22T08:00:00'}
# Data written to HBase with row key: 2023-02-22T08:00:00
# Received: {'transition_date': '2023-08-05', 'transition_hour': 11, 'line': 'KADIKOY-EMINONU', 'number_of_passenger': 11, 'station_poi_desc_cd': 'KADIKOY BALON', 'timestamp': '2023-08-05T11:00:00'}
# Data written to HBase with row key: 2023-08-05T11:00:00
# Received: {'transition_date': '2023-03-20', 'transition_hour': 18, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ITU KUZEY', 'timestamp': '2023-03-20T18:00:00'}
# Data written to HBase with row key: 2023-03-20T18:00:00
# Received: {'transition_date': '2023-12-28', 'transition_hour': 10, 'line': 'KADIKOY-EMINONU', 'number_of_passenger': 33, 'station_poi_desc_cd': 'KADIKOY BALON', 'timestamp': '2023-12-28T10:00:00'}
# Data written to HBase with row key: 2023-12-28T10:00:00
# Received: {'transition_date': '2023-05-19', 'transition_hour': 14, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 2, 'station_poi_desc_cd': 'EMNIYET', 'timestamp': '2023-05-19T14:00:00'}
# Data written to HBase with row key: 2023-05-19T14:00:00
# Received: {'transition_date': '2023-12-14', 'transition_hour': 9, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 83, 'station_poi_desc_cd': 'AYRILIKCESMESI', 'timestamp': '2023-12-14T09:00:00'}
# Data written to HBase with row key: 2023-12-14T09:00:00
# Received: {'transition_date': '2023-07-03', 'transition_hour': 8, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 194, 'station_poi_desc_cd': 'ZEYTINBURNU 2', 'timestamp': '2023-07-03T08:00:00'}
# Data written to HBase with row key: 2023-07-03T08:00:00
# Received: {'transition_date': '2023-12-13', 'transition_hour': 14, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 24, 'station_poi_desc_cd': 'ZEYTINBURNU', 'timestamp': '2023-12-13T14:00:00'}
# Data written to HBase with row key: 2023-12-13T14:00:00
# Received: {'transition_date': '2023-03-04', 'transition_hour': 14, 'line': 'ADALAR', 'number_of_passenger': 23, 'station_poi_desc_cd': 'HEYBELIADA', 'timestamp': '2023-03-04T14:00:00'}
# Data written to HBase with row key: 2023-03-04T14:00:00
# Received: {'transition_date': '2023-07-22', 'transition_hour': 8, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 8, 'station_poi_desc_cd': 'ATATURK OTO SANAYI KUZEY', 'timestamp': '2023-07-22T08:00:00'}
# Data written to HBase with row key: 2023-07-22T08:00:00
# Received: {'transition_date': '2023-11-09', 'transition_hour': 14, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'SISLI GUNEY', 'timestamp': '2023-11-09T14:00:00'}
# Data written to HBase with row key: 2023-11-09T14:00:00
# Received: {'transition_date': '2023-09-13', 'transition_hour': 8, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'CEVIZLI-1', 'timestamp': '2023-09-13T08:00:00'}
# Data written to HBase with row key: 2023-09-13T08:00:00
# Received: {'transition_date': '2023-05-03', 'transition_hour': 17, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 36, 'station_poi_desc_cd': 'FISTIKAGACI', 'timestamp': '2023-05-03T17:00:00'}
# Data written to HBase with row key: 2023-05-03T17:00:00
# Received: {'transition_date': '2023-06-07', 'transition_hour': 20, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 43, 'station_poi_desc_cd': 'ULUBATLI', 'timestamp': '2023-06-07T20:00:00'}
# Data written to HBase with row key: 2023-06-07T20:00:00
# Received: {'transition_date': '2023-10-09', 'transition_hour': 19, 'line': 'EMINONU-ALIBEYKOY', 'number_of_passenger': 3, 'station_poi_desc_cd': 'UNIVERSITE', 'timestamp': '2023-10-09T19:00:00'}
# Data written to HBase with row key: 2023-10-09T19:00:00
# Received: {'transition_date': '2023-06-05', 'transition_hour': 18, 'line': 'YENIKOY-BEYKOZ', 'number_of_passenger': 14, 'station_poi_desc_cd': 'YENIKOY', 'timestamp': '2023-06-05T18:00:00'}
# Data written to HBase with row key: 2023-06-05T18:00:00
# Received: {'transition_date': '2023-08-24', 'transition_hour': 21, 'line': 'KADIKOY-EMINONU', 'number_of_passenger': 7, 'station_poi_desc_cd': 'KADIKOY CAYIRBASI', 'timestamp': '2023-08-24T21:00:00'}
# Data written to HBase with row key: 2023-08-24T21:00:00
# Received: {'transition_date': '2023-10-06', 'transition_hour': 18, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 2, 'station_poi_desc_cd': 'AKSEMSETTIN', 'timestamp': '2023-10-06T18:00:00'}
# Data written to HBase with row key: 2023-10-06T18:00:00
# Received: {'transition_date': '2023-01-15', 'transition_hour': 15, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 2, 'station_poi_desc_cd': 'KADIKOY (BATI)', 'timestamp': '2023-01-15T15:00:00'}
# Data written to HBase with row key: 2023-01-15T15:00:00
# Received: {'transition_date': '2023-06-22', 'transition_hour': 12, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'USKUDAR-3', 'timestamp': '2023-06-22T12:00:00'}
# Data written to HBase with row key: 2023-06-22T12:00:00
# Received: {'transition_date': '2023-12-26', 'transition_hour': 22, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 3, 'station_poi_desc_cd': '4 LEVENT KUZEY', 'timestamp': '2023-12-26T22:00:00'}
# Data written to HBase with row key: 2023-12-26T22:00:00
# Received: {'transition_date': '2023-01-12', 'transition_hour': 16, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 152, 'station_poi_desc_cd': 'GAYRETTEPE', 'timestamp': '2023-01-12T16:00:00'}
# Data written to HBase with row key: 2023-01-12T16:00:00
# Received: {'transition_date': '2023-09-30', 'transition_hour': 14, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'UNALAN', 'timestamp': '2023-09-30T14:00:00'}
# Data written to HBase with row key: 2023-09-30T14:00:00
# Received: {'transition_date': '2023-01-16', 'transition_hour': 19, 'line': 'USKUDAR-EMINONU', 'number_of_passenger': 1, 'station_poi_desc_cd': 'USKUDAR', 'timestamp': '2023-01-16T19:00:00'}
# Data written to HBase with row key: 2023-01-16T19:00:00
# Received: {'transition_date': '2023-12-16', 'transition_hour': 17, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'YENIKAPI GUNEY', 'timestamp': '2023-12-16T17:00:00'}
# Data written to HBase with row key: 2023-12-16T17:00:00
# Received: {'transition_date': '2023-11-07', 'transition_hour': 17, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'LEVENT 2 KUZEY', 'timestamp': '2023-11-07T17:00:00'}
# Data written to HBase with row key: 2023-11-07T17:00:00
# Received: {'transition_date': '2023-05-23', 'transition_hour': 19, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'AYRILIKCESMESI', 'timestamp': '2023-05-23T19:00:00'}
# Data written to HBase with row key: 2023-05-23T19:00:00
# Received: {'transition_date': '2023-09-09', 'transition_hour': 10, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KADIKOY (DOGU)', 'timestamp': '2023-09-09T10:00:00'}
# Data written to HBase with row key: 2023-09-09T10:00:00
# Received: {'transition_date': '2023-12-13', 'transition_hour': 5, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 3, 'station_poi_desc_cd': 'CEVIZLI-2', 'timestamp': '2023-12-13T05:00:00'}
# Data written to HBase with row key: 2023-12-13T05:00:00
# Received: {'transition_date': '2023-11-13', 'transition_hour': 9, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 3, 'station_poi_desc_cd': 'YENIBOSNA', 'timestamp': '2023-11-13T09:00:00'}
# Data written to HBase with row key: 2023-11-13T09:00:00
# Received: {'transition_date': '2023-03-14', 'transition_hour': 15, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ESENLER', 'timestamp': '2023-03-14T15:00:00'}
# Data written to HBase with row key: 2023-03-14T15:00:00
# Received: {'transition_date': '2023-01-26', 'transition_hour': 9, 'line': 'BOSTANCI - DUDULLU', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ICERENKOY', 'timestamp': '2023-01-26T09:00:00'}
# Data written to HBase with row key: 2023-01-26T09:00:00
# Received: {'transition_date': '2023-06-08', 'transition_hour': 19, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 19, 'station_poi_desc_cd': 'KUCUKYALI-2', 'timestamp': '2023-06-08T19:00:00'}
# Data written to HBase with row key: 2023-06-08T19:00:00
# Received: {'transition_date': '2023-04-26', 'transition_hour': 8, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 4, 'station_poi_desc_cd': 'YUSUFPASA', 'timestamp': '2023-04-26T08:00:00'}
# Data written to HBase with row key: 2023-04-26T08:00:00
# Received: {'transition_date': '2023-09-03', 'transition_hour': 16, 'line': 'USKUDAR-EMINONU', 'number_of_passenger': 2, 'station_poi_desc_cd': 'USKUDAR', 'timestamp': '2023-09-03T16:00:00'}
# Data written to HBase with row key: 2023-09-03T16:00:00
# Received: {'transition_date': '2023-10-14', 'transition_hour': 21, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 7, 'station_poi_desc_cd': 'FINDIKZADE', 'timestamp': '2023-10-14T21:00:00'}
# Data written to HBase with row key: 2023-10-14T21:00:00
# Received: {'transition_date': '2023-12-08', 'transition_hour': 18, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 27, 'station_poi_desc_cd': 'ATAKOY', 'timestamp': '2023-12-08T18:00:00'}
# Data written to HBase with row key: 2023-12-08T18:00:00
# Received: {'transition_date': '2023-03-02', 'transition_hour': 16, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 12, 'station_poi_desc_cd': 'M4 KURTKOY', 'timestamp': '2023-03-02T16:00:00'}
# Data written to HBase with row key: 2023-03-02T16:00:00
# Received: {'transition_date': '2023-07-10', 'transition_hour': 16, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 3, 'station_poi_desc_cd': 'HALIC KUZEY', 'timestamp': '2023-07-10T16:00:00'}
# Data written to HBase with row key: 2023-07-10T16:00:00
# Received: {'transition_date': '2023-11-29', 'transition_hour': 10, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 5, 'station_poi_desc_cd': 'BAGCILAR', 'timestamp': '2023-11-29T10:00:00'}
# Data written to HBase with row key: 2023-11-29T10:00:00
# Received: {'transition_date': '2023-10-01', 'transition_hour': 10, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'BULGURLU', 'timestamp': '2023-10-01T10:00:00'}
# Data written to HBase with row key: 2023-10-01T10:00:00
# Received: {'transition_date': '2023-07-31', 'transition_hour': 7, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 11, 'station_poi_desc_cd': 'CAKMAK', 'timestamp': '2023-07-31T07:00:00'}
# Data written to HBase with row key: 2023-07-31T07:00:00
# Received: {'transition_date': '2023-09-09', 'transition_hour': 10, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 10, 'station_poi_desc_cd': 'UCYUZLU', 'timestamp': '2023-09-09T10:00:00'}
# Data written to HBase with row key: 2023-09-09T10:00:00
# Received: {'transition_date': '2023-05-22', 'transition_hour': 12, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 18, 'station_poi_desc_cd': 'MECIDIYEKOY BATI', 'timestamp': '2023-05-22T12:00:00'}
# Data written to HBase with row key: 2023-05-22T12:00:00
# Received: {'transition_date': '2023-11-04', 'transition_hour': 10, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 8, 'station_poi_desc_cd': 'KIPTAS VENEZIA', 'timestamp': '2023-11-04T10:00:00'}
# Data written to HBase with row key: 2023-11-04T10:00:00
# Received: {'transition_date': '2023-12-30', 'transition_hour': 14, 'line': 'ADALAR', 'number_of_passenger': 6, 'station_poi_desc_cd': 'KARTAL', 'timestamp': '2023-12-30T14:00:00'}
# Data written to HBase with row key: 2023-12-30T14:00:00
# Received: {'transition_date': '2023-01-30', 'transition_hour': 5, 'line': 'BAHARIYE-OLIMPIYAT', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ZIYA GOKALP MAH.', 'timestamp': '2023-01-30T05:00:00'}
# Data written to HBase with row key: 2023-01-30T05:00:00
# Received: {'transition_date': '2023-11-16', 'transition_hour': 14, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 21, 'station_poi_desc_cd': 'GOZTEPE', 'timestamp': '2023-11-16T14:00:00'}
# Data written to HBase with row key: 2023-11-16T14:00:00
# Received: {'transition_date': '2023-09-26', 'transition_hour': 15, 'line': 'HALIC', 'number_of_passenger': 1, 'station_poi_desc_cd': 'EYUP', 'timestamp': '2023-09-26T15:00:00'}
# Data written to HBase with row key: 2023-09-26T15:00:00
# Received: {'transition_date': '2023-10-07', 'transition_hour': 17, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 2, 'station_poi_desc_cd': 'TEKSTILKENT', 'timestamp': '2023-10-07T17:00:00'}
# Data written to HBase with row key: 2023-10-07T17:00:00
# Received: {'transition_date': '2023-04-23', 'transition_hour': 18, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KARADENIZ MAHALLESI', 'timestamp': '2023-04-23T18:00:00'}
# Data written to HBase with row key: 2023-04-23T18:00:00
# Received: {'transition_date': '2023-04-04', 'transition_hour': 15, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 2, 'station_poi_desc_cd': 'ZEYTINBURNU 2', 'timestamp': '2023-04-04T15:00:00'}
# Data written to HBase with row key: 2023-04-04T15:00:00
# Received: {'transition_date': '2023-01-18', 'transition_hour': 13, 'line': 'BOSTANCI - DUDULLU', 'number_of_passenger': 4, 'station_poi_desc_cd': 'MEVLANA', 'timestamp': '2023-01-18T13:00:00'}
# Data written to HBase with row key: 2023-01-18T13:00:00
# Received: {'transition_date': '2023-10-28', 'transition_hour': 14, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 2, 'station_poi_desc_cd': 'YENI MAHALLE', 'timestamp': '2023-10-28T14:00:00'}
# Data written to HBase with row key: 2023-10-28T14:00:00
# Received: {'transition_date': '2023-10-09', 'transition_hour': 6, 'line': 'USKUDAR-BESIKTAS', 'number_of_passenger': 4, 'station_poi_desc_cd': 'USKUDAR', 'timestamp': '2023-10-09T06:00:00'}
# Data written to HBase with row key: 2023-10-09T06:00:00
# Received: {'transition_date': '2023-03-16', 'transition_hour': 8, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 16, 'station_poi_desc_cd': 'SIRKECI', 'timestamp': '2023-03-16T08:00:00'}
# Data written to HBase with row key: 2023-03-16T08:00:00
# Received: {'transition_date': '2023-11-15', 'transition_hour': 19, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'MAHMUTBEY M7 HOL 2', 'timestamp': '2023-11-15T19:00:00'}
# Data written to HBase with row key: 2023-11-15T19:00:00
# Received: {'transition_date': '2023-06-29', 'transition_hour': 12, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 2, 'station_poi_desc_cd': 'TUZLA', 'timestamp': '2023-06-29T12:00:00'}
# Data written to HBase with row key: 2023-06-29T12:00:00
# Received: {'transition_date': '2023-11-13', 'transition_hour': 11, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KARADENIZ MAH. BATI', 'timestamp': '2023-11-13T11:00:00'}
# Data written to HBase with row key: 2023-11-13T11:00:00
# Received: {'transition_date': '2023-01-25', 'transition_hour': 11, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 7, 'station_poi_desc_cd': 'YAKACIK (DOGU)', 'timestamp': '2023-01-25T11:00:00'}
# Data written to HBase with row key: 2023-01-25T11:00:00
# Received: {'transition_date': '2023-10-09', 'transition_hour': 16, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ESENKENT CEVIZLI', 'timestamp': '2023-10-09T16:00:00'}
# Data written to HBase with row key: 2023-10-09T16:00:00
# Received: {'transition_date': '2023-03-20', 'transition_hour': 8, 'line': 'GAYRETTEPE-ISTANBUL YENI HAVALIMA', 'number_of_passenger': 2, 'station_poi_desc_cd': 'GOKTURK', 'timestamp': '2023-03-20T08:00:00'}
# Data written to HBase with row key: 2023-03-20T08:00:00
# Received: {'transition_date': '2023-05-26', 'transition_hour': 10, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 1, 'station_poi_desc_cd': 'YUSUFPASA', 'timestamp': '2023-05-26T10:00:00'}
# Data written to HBase with row key: 2023-05-26T10:00:00
# Received: {'transition_date': '2023-07-25', 'transition_hour': 22, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 2, 'station_poi_desc_cd': 'MECIDIYEKOY BATI', 'timestamp': '2023-07-25T22:00:00'}
# Data written to HBase with row key: 2023-07-25T22:00:00
# Received: {'transition_date': '2023-09-10', 'transition_hour': 17, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'BAYRAMPASA', 'timestamp': '2023-09-10T17:00:00'}
# Data written to HBase with row key: 2023-09-10T17:00:00
# Received: {'transition_date': '2023-04-23', 'transition_hour': 11, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 4, 'station_poi_desc_cd': 'MECIDIYEKOY BATI', 'timestamp': '2023-04-23T11:00:00'}
# Data written to HBase with row key: 2023-04-23T11:00:00
# Received: {'transition_date': '2023-04-19', 'transition_hour': 21, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 5, 'station_poi_desc_cd': 'TURGUT OZAL', 'timestamp': '2023-04-19T21:00:00'}
# Data written to HBase with row key: 2023-04-19T21:00:00
# Received: {'transition_date': '2023-05-15', 'transition_hour': 11, 'line': 'BOSTANCI - DUDULLU', 'number_of_passenger': 4, 'station_poi_desc_cd': 'HUZUR', 'timestamp': '2023-05-15T11:00:00'}
# Data written to HBase with row key: 2023-05-15T11:00:00
# Received: {'transition_date': '2023-02-03', 'transition_hour': 18, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 1800, 'station_poi_desc_cd': 'USKUDAR 1', 'timestamp': '2023-02-03T18:00:00'}
# Data written to HBase with row key: 2023-02-03T18:00:00
# Received: {'transition_date': '2023-06-15', 'transition_hour': 5, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 5, 'station_poi_desc_cd': 'MALTEPE', 'timestamp': '2023-06-15T05:00:00'}
# Data written to HBase with row key: 2023-06-15T05:00:00
# Received: {'transition_date': '2023-09-29', 'transition_hour': 8, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 4, 'station_poi_desc_cd': 'BOSTANCI-1', 'timestamp': '2023-09-29T08:00:00'}
# Data written to HBase with row key: 2023-09-29T08:00:00
# Received: {'transition_date': '2023-05-12', 'transition_hour': 16, 'line': 'EMINONU-USKUDAR', 'number_of_passenger': 2, 'station_poi_desc_cd': 'KARAKOY', 'timestamp': '2023-05-12T16:00:00'}
# Data written to HBase with row key: 2023-05-12T16:00:00
# Received: {'transition_date': '2023-03-26', 'transition_hour': 8, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 5, 'station_poi_desc_cd': 'UMRANIYE', 'timestamp': '2023-03-26T08:00:00'}
# Data written to HBase with row key: 2023-03-26T08:00:00
# Received: {'transition_date': '2023-04-19', 'transition_hour': 14, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 2, 'station_poi_desc_cd': 'USKUDAR 1', 'timestamp': '2023-04-19T14:00:00'}
# Data written to HBase with row key: 2023-04-19T14:00:00
# Received: {'transition_date': '2023-06-06', 'transition_hour': 0, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KARTAL', 'timestamp': '2023-06-06T00:00:00'}
# Data written to HBase with row key: 2023-06-06T00:00:00
# Received: {'transition_date': '2023-12-27', 'transition_hour': 7, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 5, 'station_poi_desc_cd': 'ULUBATLI', 'timestamp': '2023-12-27T07:00:00'}
# Data written to HBase with row key: 2023-12-27T07:00:00
# Received: {'transition_date': '2023-01-13', 'transition_hour': 10, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 103, 'station_poi_desc_cd': 'YENIKAPI-2', 'timestamp': '2023-01-13T10:00:00'}
# Data written to HBase with row key: 2023-01-13T10:00:00
# Received: {'transition_date': '2023-05-04', 'transition_hour': 10, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'TAVSANTEPE (DOGU)', 'timestamp': '2023-05-04T10:00:00'}
# Data written to HBase with row key: 2023-05-04T10:00:00
# Received: {'transition_date': '2023-09-03', 'transition_hour': 12, 'line': 'HALIC', 'number_of_passenger': 30, 'station_poi_desc_cd': 'EYUP', 'timestamp': '2023-09-03T12:00:00'}
# Data written to HBase with row key: 2023-09-03T12:00:00
# Received: {'transition_date': '2023-04-14', 'transition_hour': 23, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 9, 'station_poi_desc_cd': 'VEZNECILER GUNEY', 'timestamp': '2023-04-14T23:00:00'}
# Data written to HBase with row key: 2023-04-14T23:00:00
# Received: {'transition_date': '2023-08-03', 'transition_hour': 12, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 95, 'station_poi_desc_cd': 'ULUBATLI', 'timestamp': '2023-08-03T12:00:00'}
# Data written to HBase with row key: 2023-08-03T12:00:00
# Received: {'transition_date': '2023-11-30', 'transition_hour': 15, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 7, 'station_poi_desc_cd': 'YESILYURT', 'timestamp': '2023-11-30T15:00:00'}
# Data written to HBase with row key: 2023-11-30T15:00:00
# Received: {'transition_date': '2023-04-10', 'transition_hour': 20, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 2, 'station_poi_desc_cd': 'ESENLER', 'timestamp': '2023-04-10T20:00:00'}
# Data written to HBase with row key: 2023-04-10T20:00:00
# Received: {'transition_date': '2023-05-03', 'transition_hour': 7, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ZEYTINBURNU', 'timestamp': '2023-05-03T07:00:00'}
# Data written to HBase with row key: 2023-05-03T07:00:00
# Received: {'transition_date': '2023-02-27', 'transition_hour': 11, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 39, 'station_poi_desc_cd': 'SAGMALCILAR', 'timestamp': '2023-02-27T11:00:00'}
# Data written to HBase with row key: 2023-02-27T11:00:00
# Received: {'transition_date': '2023-12-21', 'transition_hour': 5, 'line': 'EMINONU-ALIBEYKOY', 'number_of_passenger': 2, 'station_poi_desc_cd': 'EYUP DEVLET HASTANESI', 'timestamp': '2023-12-21T05:00:00'}
# Data written to HBase with row key: 2023-12-21T05:00:00
# Received: {'transition_date': '2023-09-16', 'transition_hour': 17, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KUCUKCEKMECE', 'timestamp': '2023-09-16T17:00:00'}
# Data written to HBase with row key: 2023-09-16T17:00:00
# Received: {'transition_date': '2023-06-01', 'transition_hour': 14, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'LEVENT 2 KUZEY', 'timestamp': '2023-06-01T14:00:00'}
# Data written to HBase with row key: 2023-06-01T14:00:00
# Received: {'transition_date': '2023-04-08', 'transition_hour': 9, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'SIRKECI-1', 'timestamp': '2023-04-08T09:00:00'}
# Data written to HBase with row key: 2023-04-08T09:00:00
# Received: {'transition_date': '2023-10-29', 'transition_hour': 16, 'line': 'EMINONU-ALIBEYKOY', 'number_of_passenger': 6, 'station_poi_desc_cd': 'EMINONU', 'timestamp': '2023-10-29T16:00:00'}
# Data written to HBase with row key: 2023-10-29T16:00:00
# Received: {'transition_date': '2023-10-28', 'transition_hour': 13, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'BAKIRKOY-2', 'timestamp': '2023-10-28T13:00:00'}
# Data written to HBase with row key: 2023-10-28T13:00:00
# Received: {'transition_date': '2023-03-04', 'transition_hour': 21, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 2, 'station_poi_desc_cd': 'METRIS', 'timestamp': '2023-03-04T21:00:00'}
# Data written to HBase with row key: 2023-03-04T21:00:00
# Received: {'transition_date': '2023-04-26', 'transition_hour': 16, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'TERAZIDERE', 'timestamp': '2023-04-26T16:00:00'}
# Data written to HBase with row key: 2023-04-26T16:00:00
# Received: {'transition_date': '2023-01-18', 'transition_hour': 23, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 2, 'station_poi_desc_cd': 'SISLI 2 KUZEY', 'timestamp': '2023-01-18T23:00:00'}
# Data written to HBase with row key: 2023-01-18T23:00:00
# Received: {'transition_date': '2023-04-11', 'transition_hour': 9, 'line': 'LEVENT-HISAR USTU', 'number_of_passenger': 2, 'station_poi_desc_cd': 'LEVENT DOGU KONKORS', 'timestamp': '2023-04-11T09:00:00'}
# Data written to HBase with row key: 2023-04-11T09:00:00
# Received: {'transition_date': '2023-01-30', 'transition_hour': 12, 'line': 'GAYRETTEPE-ISTANBUL YENI HAVALIMA', 'number_of_passenger': 2, 'station_poi_desc_cd': 'GOKTURK', 'timestamp': '2023-01-30T12:00:00'}
# Data written to HBase with row key: 2023-01-30T12:00:00
# Received: {'transition_date': '2023-07-23', 'transition_hour': 17, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 1, 'station_poi_desc_cd': 'MAHMUTBEY M7 HOL 4', 'timestamp': '2023-07-23T17:00:00'}
# Data written to HBase with row key: 2023-07-23T17:00:00
# Received: {'transition_date': '2023-04-07', 'transition_hour': 14, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 4, 'station_poi_desc_cd': 'CAMI', 'timestamp': '2023-04-07T14:00:00'}
# Data written to HBase with row key: 2023-04-07T14:00:00
# Received: {'transition_date': '2023-03-31', 'transition_hour': 8, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 2, 'station_poi_desc_cd': 'TEKSTILKENT', 'timestamp': '2023-03-31T08:00:00'}
# Data written to HBase with row key: 2023-03-31T08:00:00
# Received: {'transition_date': '2023-03-07', 'transition_hour': 17, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 6, 'station_poi_desc_cd': 'TERSANE-1', 'timestamp': '2023-03-07T17:00:00'}
# Data written to HBase with row key: 2023-03-07T17:00:00
# Received: {'transition_date': '2023-05-29', 'transition_hour': 16, 'line': 'TUNEL', 'number_of_passenger': 5, 'station_poi_desc_cd': 'BEYOGLU', 'timestamp': '2023-05-29T16:00:00'}
# Data written to HBase with row key: 2023-05-29T16:00:00
# Received: {'transition_date': '2023-11-24', 'transition_hour': 14, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 4, 'station_poi_desc_cd': 'SUADIYE', 'timestamp': '2023-11-24T14:00:00'}
# Data written to HBase with row key: 2023-11-24T14:00:00
# Received: {'transition_date': '2023-02-03', 'transition_hour': 13, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ESENKENT CEVIZLI', 'timestamp': '2023-02-03T13:00:00'}
# Data written to HBase with row key: 2023-02-03T13:00:00
# Received: {'transition_date': '2023-06-22', 'transition_hour': 8, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 2, 'station_poi_desc_cd': 'CEKMEKOY 2', 'timestamp': '2023-06-22T08:00:00'}
# Data written to HBase with row key: 2023-06-22T08:00:00
# Received: {'transition_date': '2023-01-17', 'transition_hour': 11, 'line': 'HALIC', 'number_of_passenger': 1, 'station_poi_desc_cd': 'USKUDAR', 'timestamp': '2023-01-17T11:00:00'}
# Data written to HBase with row key: 2023-01-17T11:00:00
# Received: {'transition_date': '2023-02-11', 'transition_hour': 14, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KAGITHANE BATI', 'timestamp': '2023-02-11T14:00:00'}
# Data written to HBase with row key: 2023-02-11T14:00:00
# Received: {'transition_date': '2023-11-06', 'transition_hour': 13, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 4, 'station_poi_desc_cd': 'SABIHA GOKCEN', 'timestamp': '2023-11-06T13:00:00'}
# Data written to HBase with row key: 2023-11-06T13:00:00
# Received: {'transition_date': '2023-12-13', 'transition_hour': 12, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KARTALTEPE', 'timestamp': '2023-12-13T12:00:00'}
# Data written to HBase with row key: 2023-12-13T12:00:00
# Received: {'transition_date': '2023-05-15', 'transition_hour': 6, 'line': 'EMINONU-ALIBEYKOY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'FENER', 'timestamp': '2023-05-15T06:00:00'}
# Data written to HBase with row key: 2023-05-15T06:00:00
# Received: {'transition_date': '2023-08-17', 'transition_hour': 16, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 4, 'station_poi_desc_cd': 'CIRCIR DOGU', 'timestamp': '2023-08-17T16:00:00'}
# Data written to HBase with row key: 2023-08-17T16:00:00
# Received: {'transition_date': '2023-10-18', 'transition_hour': 11, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 80, 'station_poi_desc_cd': 'OSMANBEY 2 GUNEY', 'timestamp': '2023-10-18T11:00:00'}
# Data written to HBase with row key: 2023-10-18T11:00:00
# Received: {'transition_date': '2023-09-26', 'transition_hour': 20, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 2, 'station_poi_desc_cd': 'SIRKECI-2', 'timestamp': '2023-09-26T20:00:00'}
# Data written to HBase with row key: 2023-09-26T20:00:00
# Received: {'transition_date': '2023-04-27', 'transition_hour': 14, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 104, 'station_poi_desc_cd': 'TAKSIM GUNEY', 'timestamp': '2023-04-27T14:00:00'}
# Data written to HBase with row key: 2023-04-27T14:00:00
# Received: {'transition_date': '2023-12-03', 'transition_hour': 7, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ORUCREIS DOGU', 'timestamp': '2023-12-03T07:00:00'}
# Data written to HBase with row key: 2023-12-03T07:00:00
# Received: {'transition_date': '2023-02-11', 'transition_hour': 20, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 2, 'station_poi_desc_cd': 'BAGCILAR MEYDAN', 'timestamp': '2023-02-11T20:00:00'}
# Data written to HBase with row key: 2023-02-11T20:00:00
# Received: {'transition_date': '2023-01-03', 'transition_hour': 21, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 3, 'station_poi_desc_cd': 'CEKMEKOY 2', 'timestamp': '2023-01-03T21:00:00'}
# ...
# Data written to HBase with row key: 2023-09-28T08:00:00
# Received: {'transition_date': '2023-11-14', 'transition_hour': 6, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 4, 'station_poi_desc_cd': 'YESILKOY', 'timestamp': '2023-11-14T06:00:00'}
# Data written to HBase with row key: 2023-11-14T06:00:00
# Received: {'transition_date': '2023-02-09', 'transition_hour': 10, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 6, 'station_poi_desc_cd': 'CAGLAYAN BATI', 'timestamp': '2023-02-09T10:00:00'}
# Data written to HBase with row key: 2023-02-09T10:00:00
# Received: {'transition_date': '2023-06-07', 'transition_hour': 15, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 4, 'station_poi_desc_cd': 'HASEKI', 'timestamp': '2023-06-07T15:00:00'}
# Data written to HBase with row key: 2023-06-07T15:00:00
# Received: {'transition_date': '2023-01-18', 'transition_hour': 11, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ITU KUZEY', 'timestamp': '2023-01-18T11:00:00'}
# Data written to HBase with row key: 2023-01-18T11:00:00
# Received: {'transition_date': '2023-08-15', 'transition_hour': 16, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 1, 'station_poi_desc_cd': 'YUSUFPASA', 'timestamp': '2023-08-15T16:00:00'}
# Data written to HBase with row key: 2023-08-15T16:00:00
# Received: {'transition_date': '2023-01-18', 'transition_hour': 20, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 2, 'station_poi_desc_cd': 'ATATURK OGRENCI YURDU', 'timestamp': '2023-01-18T20:00:00'}
# Data written to HBase with row key: 2023-01-18T20:00:00
# Received: {'transition_date': '2023-12-21', 'transition_hour': 15, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 18, 'station_poi_desc_cd': 'YENISAHRA', 'timestamp': '2023-12-21T15:00:00'}
# Data written to HBase with row key: 2023-12-21T15:00:00
# Received: {'transition_date': '2023-02-19', 'transition_hour': 11, 'line': 'KADIKOY-EMINONU', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KADIKOY BALON', 'timestamp': '2023-02-19T11:00:00'}
# Data written to HBase with row key: 2023-02-19T11:00:00
# Received: {'transition_date': '2023-08-21', 'transition_hour': 17, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 5, 'station_poi_desc_cd': 'FEVZI CAKMAK', 'timestamp': '2023-08-21T17:00:00'}
# Data written to HBase with row key: 2023-08-21T17:00:00
# Received: {'transition_date': '2023-07-12', 'transition_hour': 17, 'line': 'ASIYAN-USKUDAR', 'number_of_passenger': 8, 'station_poi_desc_cd': nan, 'timestamp': '2023-07-12T17:00:00'}
# Data written to HBase with row key: 2023-07-12T17:00:00
# Received: {'transition_date': '2023-04-18', 'transition_hour': 20, 'line': 'USKUDAR-EMINONU', 'number_of_passenger': 1, 'station_poi_desc_cd': 'USKUDAR', 'timestamp': '2023-04-18T20:00:00'}
# Data written to HBase with row key: 2023-04-18T20:00:00
# Received: {'transition_date': '2023-01-22', 'transition_hour': 21, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 11, 'station_poi_desc_cd': 'CAPA', 'timestamp': '2023-01-22T21:00:00'}
# Data written to HBase with row key: 2023-01-22T21:00:00
# Received: {'transition_date': '2023-10-01', 'transition_hour': 22, 'line': 'GAYRETTEPE-ISTANBUL YENI HAVALIMA', 'number_of_passenger': 7, 'station_poi_desc_cd': 'GOKTURK', 'timestamp': '2023-10-01T22:00:00'}
# Data written to HBase with row key: 2023-10-01T22:00:00
# Received: {'transition_date': '2023-07-19', 'transition_hour': 17, 'line': 'YENIKAPI - HAVALIMANI', 'number_of_passenger': 2, 'station_poi_desc_cd': 'ZEYTINBURNU', 'timestamp': '2023-07-19T17:00:00'}
# Data written to HBase with row key: 2023-07-19T17:00:00
# Received: {'transition_date': '2023-04-16', 'transition_hour': 21, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 2, 'station_poi_desc_cd': 'FATIH', 'timestamp': '2023-04-16T21:00:00'}
# Data written to HBase with row key: 2023-04-16T21:00:00
# Received: {'transition_date': '2023-09-30', 'transition_hour': 22, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 2, 'station_poi_desc_cd': 'MAHMUTBEY M7 HOL 2', 'timestamp': '2023-09-30T22:00:00'}
# Data written to HBase with row key: 2023-09-30T22:00:00
# Received: {'transition_date': '2023-09-26', 'transition_hour': 6, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 47, 'station_poi_desc_cd': 'MERKEZEFENDI', 'timestamp': '2023-09-26T06:00:00'}
# Data written to HBase with row key: 2023-09-26T06:00:00
# Received: {'transition_date': '2023-06-27', 'transition_hour': 9, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 4, 'station_poi_desc_cd': 'SIRKECI', 'timestamp': '2023-06-27T09:00:00'}
# Data written to HBase with row key: 2023-06-27T09:00:00
# Received: {'transition_date': '2023-04-06', 'transition_hour': 10, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'YENIKAPI GUNEY', 'timestamp': '2023-04-06T10:00:00'}
# Data written to HBase with row key: 2023-04-06T10:00:00
# Received: {'transition_date': '2023-10-28', 'transition_hour': 17, 'line': 'USKUDAR-EMINONU', 'number_of_passenger': 1, 'station_poi_desc_cd': 'USKUDAR', 'timestamp': '2023-10-28T17:00:00'}
# Data written to HBase with row key: 2023-10-28T17:00:00
# Received: {'transition_date': '2023-01-14', 'transition_hour': 5, 'line': 'KABATAS-MAHMUTBEY', 'number_of_passenger': 6, 'station_poi_desc_cd': 'KAZIMKARABEKIR', 'timestamp': '2023-01-14T05:00:00'}
# Data written to HBase with row key: 2023-01-14T05:00:00
# Received: {'transition_date': '2023-12-08', 'transition_hour': 9, 'line': 'BAHARIYE-OLIMPIYAT', 'number_of_passenger': 2, 'station_poi_desc_cd': 'BAHARIYE', 'timestamp': '2023-12-08T09:00:00'}
# Data written to HBase with row key: 2023-12-08T09:00:00
# Received: {'transition_date': '2023-07-31', 'transition_hour': 9, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 4, 'station_poi_desc_cd': 'YENI MAHALLE', 'timestamp': '2023-07-31T09:00:00'}
# Data written to HBase with row key: 2023-07-31T09:00:00
# Received: {'transition_date': '2023-02-27', 'transition_hour': 17, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 2, 'station_poi_desc_cd': 'PAZARTEKKE', 'timestamp': '2023-02-27T17:00:00'}
# Data written to HBase with row key: 2023-02-27T17:00:00
# Received: {'transition_date': '2023-04-20', 'transition_hour': 18, 'line': 'KIRAZLI-BASAKSEHIR/METROKENT', 'number_of_passenger': 1, 'station_poi_desc_cd': 'ONURKENT', 'timestamp': '2023-04-20T18:00:00'}
# Data written to HBase with row key: 2023-04-20T18:00:00
# Received: {'transition_date': '2023-09-27', 'transition_hour': 16, 'line': 'USKUDAR-CEKMEKOY', 'number_of_passenger': 4, 'station_poi_desc_cd': 'BAGLARBASI', 'timestamp': '2023-09-27T16:00:00'}
# Data written to HBase with row key: 2023-09-27T16:00:00
# Received: {'transition_date': '2023-04-23', 'transition_hour': 18, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 1, 'station_poi_desc_cd': 'USKUDAR-3', 'timestamp': '2023-04-23T18:00:00'}
# Data written to HBase with row key: 2023-04-23T18:00:00
# Received: {'transition_date': '2023-03-09', 'transition_hour': 13, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 7, 'station_poi_desc_cd': 'SISLI GUNEY', 'timestamp': '2023-03-09T13:00:00'}
# Data written to HBase with row key: 2023-03-09T13:00:00
# Received: {'transition_date': '2023-04-18', 'transition_hour': 5, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 1, 'station_poi_desc_cd': 'SAGMALCILAR', 'timestamp': '2023-04-18T05:00:00'}
# Data written to HBase with row key: 2023-04-18T05:00:00
# Received: {'transition_date': '2023-07-12', 'transition_hour': 12, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 1, 'station_poi_desc_cd': 'VATAN', 'timestamp': '2023-07-12T12:00:00'}
# Data written to HBase with row key: 2023-07-12T12:00:00
# Received: {'transition_date': '2023-12-08', 'transition_hour': 16, 'line': 'BOSTANCI - DUDULLU', 'number_of_passenger': 2, 'station_poi_desc_cd': 'KOZYATAGI', 'timestamp': '2023-12-08T16:00:00'}
# Data written to HBase with row key: 2023-12-08T16:00:00
# Received: {'transition_date': '2023-03-26', 'transition_hour': 21, 'line': 'EMINONU-ALIBEYKOY', 'number_of_passenger': 3, 'station_poi_desc_cd': 'ALIBEYKOY', 'timestamp': '2023-03-26T21:00:00'}
# Data written to HBase with row key: 2023-03-26T21:00:00
# Received: {'transition_date': '2023-07-01', 'transition_hour': 18, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 1, 'station_poi_desc_cd': 'CEBECI', 'timestamp': '2023-07-01T18:00:00'}
# Data written to HBase with row key: 2023-07-01T18:00:00
# Received: {'transition_date': '2023-11-11', 'transition_hour': 12, 'line': 'BOSTANCI - DUDULLU', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KOZYATAGI', 'timestamp': '2023-11-11T12:00:00'}
# Data written to HBase with row key: 2023-11-11T12:00:00
# Received: {'transition_date': '2023-12-13', 'transition_hour': 15, 'line': 'TUNEL', 'number_of_passenger': 1, 'station_poi_desc_cd': 'KARAKOY', 'timestamp': '2023-12-13T15:00:00'}
# Data written to HBase with row key: 2023-12-13T15:00:00
# Received: {'transition_date': '2023-12-05', 'transition_hour': 15, 'line': 'TUNEL', 'number_of_passenger': 7, 'station_poi_desc_cd': 'KARAKOY', 'timestamp': '2023-12-05T15:00:00'}
# Data written to HBase with row key: 2023-12-05T15:00:00
# Received: {'transition_date': '2023-03-09', 'transition_hour': 12, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 3, 'station_poi_desc_cd': 'HASTANE (BATI)', 'timestamp': '2023-03-09T12:00:00'}
# Data written to HBase with row key: 2023-03-09T12:00:00
# Received: {'transition_date': '2023-04-03', 'transition_hour': 14, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 5, 'station_poi_desc_cd': 'SISHANE KUZEY', 'timestamp': '2023-04-03T14:00:00'}
# Data written to HBase with row key: 2023-04-03T14:00:00
# Received: {'transition_date': '2023-11-23', 'transition_hour': 17, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 3, 'station_poi_desc_cd': 'SUADIYE', 'timestamp': '2023-11-23T17:00:00'}
# Data written to HBase with row key: 2023-11-23T17:00:00
# Received: {'transition_date': '2023-12-06', 'transition_hour': 18, 'line': 'TOPKAPI-HABIBLER', 'number_of_passenger': 1, 'station_poi_desc_cd': 'EDIRNEKAPI', 'timestamp': '2023-12-06T18:00:00'}
# Data written to HBase with row key: 2023-12-06T18:00:00
# Received: {'transition_date': '2023-12-30', 'transition_hour': 17, 'line': 'YENIKAPI - HACIOSMAN', 'number_of_passenger': 1, 'station_poi_desc_cd': 'OSMANBEY KUZEY', 'timestamp': '2023-12-30T17:00:00'}
# Data written to HBase with row key: 2023-12-30T17:00:00
# Received: {'transition_date': '2023-09-08', 'transition_hour': 14, 'line': 'ADALAR', 'number_of_passenger': 1, 'station_poi_desc_cd': 'BOSTANCI', 'timestamp': '2023-09-08T14:00:00'}
# Data written to HBase with row key: 2023-09-08T14:00:00
# Received: {'transition_date': '2023-05-12', 'transition_hour': 21, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 86, 'station_poi_desc_cd': 'KAZLICESME', 'timestamp': '2023-05-12T21:00:00'}
# Data written to HBase with row key: 2023-05-12T21:00:00
# Received: {'transition_date': '2023-07-01', 'transition_hour': 22, 'line': 'HALKALI - GEBZE', 'number_of_passenger': 10, 'station_poi_desc_cd': 'ICMELER', 'timestamp': '2023-07-01T22:00:00'}
# Data written to HBase with row key: 2023-07-01T22:00:00
# Received: {'transition_date': '2023-11-03', 'transition_hour': 8, 'line': 'KADIKOY-KARTAL', 'number_of_passenger': 327, 'station_poi_desc_cd': 'KUCUKYALI', 'timestamp': '2023-11-03T08:00:00'}
# Data written to HBase with row key: 2023-11-03T08:00:00
# Received: {'transition_date': '2023-12-09', 'transition_hour': 14, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 4, 'station_poi_desc_cd': 'KARAKOY', 'timestamp': '2023-12-09T14:00:00'}
# Data written to HBase with row key: 2023-12-09T14:00:00
# Received: {'transition_date': '2023-10-17', 'transition_hour': 10, 'line': 'KABATAS-BAGCILAR', 'number_of_passenger': 2, 'station_poi_desc_cd': 'YUSUFPASA', 'timestamp': '2023-10-17T10:00:00'}
# Data written to HBase with row key: 2023-10-17T10:00:00
# Received: {'transition_date': '2023-06-11', 'transition_hour': 13, 'line': 'KARAKOY-Y.KADIKOY', 'number_of_passenger': 2, 'station_poi_desc_cd': 'KARAKOY', 'timestamp': '2023-06-11T13:00:00'}
# Data written to HBase with row key: 2023-06-11T13:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 34
#      32 # Consume messages and write to HBase
#      33 print("Listening for messages...")
# ---> 34 for message in consumer:
#      35     data = message.value  # Deserialize the message
#      36     print(f"Received: {data}")
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1203, in KafkaConsumer.__next__(self)
#    1201     return self.next_v1()
#    1202 else:
# -> 1203     return self.next_v2()
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1211, in KafkaConsumer.next_v2(self)
#    1209     self._iterator = self._message_generator_v2()
#    1210 try:
# -> 1211     return next(self._iterator)
#    1212 except StopIteration:
#    1213     self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:1126, in KafkaConsumer._message_generator_v2(self)
#    1124 def _message_generator_v2(self):
#    1125     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1126     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1127     for tp, records in record_map.items():
#    1128         # Generators are stateful, and it is possible that the tp / records
#    1129         # here may become stale during iteration -- i.e., we seek to a
#    1130         # different offset, pause consumption, or lose assignment.
#    1131         for record in records:
#    1132             # is_fetchable(tp) should handle assignment changes and offset
#    1133             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1134             # outer function destroying the existing iterator/generator
#    1135             # via self._iterator = None
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:663, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     661 remaining = timeout_ms
#     662 while not self._closed:
# --> 663     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     664     if records:
#     665         return records
#
# File ~\anaconda3\Lib\site-packages\kafka\consumer\group.py:712, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     709     self._client.poll(timeout_ms=0)
#     711 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 712 self._client.poll(timeout_ms=timeout_ms)
#     713 # after the long poll, we should check whether the group needs to rebalance
#     714 # prior to returning data so that the group can stabilize faster
#     715 if self._coordinator.need_rejoin():
#
# File ~\anaconda3\Lib\site-packages\kafka\client_async.py:601, in KafkaClient.poll(self, timeout_ms, future)
#     598             timeout = min(timeout, self.config['retry_backoff_ms'])
#     599         timeout = max(0, timeout)  # avoid negative timeouts
# --> 601     self._poll(timeout / 1000)
#     603 # called without the lock to avoid deadlock potential
#     604 # if handlers need to acquire locks
#     605 responses.extend(self._fire_pending_completed_requests())
#
# File ~\anaconda3\Lib\site-packages\kafka\client_async.py:633, in KafkaClient._poll(self, timeout)
#     630 self._register_send_sockets()
#     632 start_select = time.time()
# --> 633 ready = self._selector.select(timeout)
#     634 end_select = time.time()
#     635 if self._sensors:
#
# File ~\anaconda3\Lib\selectors.py:323, in SelectSelector.select(self, timeout)
#     321 ready = []
#     322 try:
# --> 323     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324 except InterruptedError:
#     325     return ready
#
# File ~\anaconda3\Lib\selectors.py:314, in SelectSelector._select(self, r, w, _, timeout)
#     313 def _select(self, r, w, _, timeout=None):
# --> 314     r, w, x = select.select(r, w, w, timeout)
#     315     return r, w + x, []
#
# KeyboardInterrupt:

# %% [markdown]
# # Show as Pandas DF

# %%
import happybase
import pandas as pd

# Connect to HBase Thrift Server
connection = happybase.Connection(host='localhost')  # Replace 'localhost' with your HBase server address
connection.open()

# Define the table name
table_name = 'public_transport'

# Access the HBase table
table = connection.table(table_name)

# Initialize a list to hold the rows
rows = []

# Scan the table and populate the list
for key, data in table.scan():
    row = {'row_key': key.decode('utf-8')}  # Start with the row key
    for column, value in data.items():
        row[column.decode('utf-8')] = value.decode('utf-8')  # Decode column names and values
    rows.append(row)

# Convert the list of rows into a Pandas DataFrame
df = pd.DataFrame(rows)

# Display the DataFrame
print("DataFrame created from HBase table:")
df
# Out:
# DataFrame created from HBase table:
#                   row_key               cf:line cf:number_of_passenger  \
# 0     2023-01-01T03:00:00      USKUDAR-CEKMEKOY                      3
# 1     2023-01-01T06:00:00       HALKALI - GEBZE                      2
# 2     2023-01-01T08:00:00       HALKALI - GEBZE                      1
# 3     2023-01-01T11:00:00     EMINONU-ALIBEYKOY                      1
# 4     2023-01-01T14:00:00     KARAKOY-Y.KADIKOY                      1
# ...                   ...                   ...                    ...
# 3478  2023-12-31T18:00:00        KADIKOY-KARTAL                    156
# 3479  2023-12-31T19:00:00  YENIKAPI - HACIOSMAN                      1
# 3480  2023-12-31T21:00:00  YENIKAPI - HACIOSMAN                      1
# 3481  2023-12-31T22:00:00        KADIKOY-KARTAL                      6
# 3482  2023-12-31T23:00:00      KABATAS-BAGCILAR                      4
#
#      cf:station_poi_desc_cd         cf:timestamp cf:transition_date  \
# 0              ALTUNIZADE 1  2023-01-01T03:00:00         2023-01-01
# 1            AYRILIKCESMESI  2023-01-01T06:00:00         2023-01-01
# 2                   ERENKOY  2023-01-01T08:00:00         2023-01-01
# 3                 ALIBEYKOY  2023-01-01T11:00:00         2023-01-01
# 4                   KARAKOY  2023-01-01T14:00:00         2023-01-01
# ...                     ...                  ...                ...
# 3478               HUZUREVI  2023-12-31T18:00:00         2023-12-31
# 3479         YENIKAPI KUZEY  2023-12-31T19:00:00         2023-12-31
# 3480       OSMANBEY 2 GUNEY  2023-12-31T21:00:00         2023-12-31
# 3481              KUCUKYALI  2023-12-31T22:00:00         2023-12-31
# 3482             FINDIKZADE  2023-12-31T23:00:00         2023-12-31
#
#      cf:transition_hour
# 0                     3
# 1                     6
# 2                     8
# 3                    11
# 4                    14
# ...                 ...
# 3478                 18
# 3479                 19
# 3480                 21
# 3481                 22
# 3482                 23
#
# [3483 rows x 7 columns]
